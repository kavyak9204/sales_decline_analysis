# %%
import pandas as pd
df = pd.read_csv("/content/pandas_practise.csv")

# %%
df.head(4)
# Out:
#    Order_ID        Date Customer_ID Customer_Name Region     Product  \
# 0      1001  2024-01-05        C001          Ravi  South      Laptop
# 1      1002  2024-01-06        C002        Anjali  North       Phone
# 2      1003  2024-01-07        C003         Rohit   East  Headphones
# 3      1004  2024-01-08        C004         Meena   West      Tablet
#
#       Category  Quantity  Price  Discount Payment_Method
# 0  Electronics         1  55000      5000            UPI
# 1  Electronics         2  20000      2000           Card
# 2  Accessories         3   1500       100           Cash
# 3  Electronics         1  30000      3000            UPI

# %%
df['final_price'] = df['Price'] - df['Discount']

# %%
df['Total_sales'] = df['Quantity']* df['final_price']

# %%
df =df.rename(columns={'customer_Name' : 'Name'})

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Date, Customer_ID, Customer_Name, Region, Product, Category, Quantity, Price, Discount, Payment_Method, final_price, Total_sales]
# Index: []

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['Region']=='South']
# Out:
#     Order_ID        Date Customer_ID Customer_Name Region     Product  \
# 0       1001  2024-01-05        C001          Ravi  South      Laptop
# 4       1005  2024-01-09        C005          Amit  South       Mouse
# 8       1009  2024-01-13        C009         Vikas  South       Phone
# 10      1011  2024-01-15        C001          Ravi  South       Mouse
# 14      1015  2024-01-19        C005          Amit  South       Phone
# 18      1019  2024-01-23        C009         Vikas  South    Keyboard
# 20      1021  2024-01-25        C001          Ravi  South     Monitor
# 24      1025  2024-01-29        C005          Amit  South  Headphones
# 28      1029  2024-02-02        C009         Vikas  South      Laptop
#
#        Category  Quantity  Price  Discount Payment_Method  final_price  \
# 0   Electronics         1  55000      5000            UPI        50000
# 4   Accessories         4    500        50           Cash          450
# ...

# %%
df[df['final_price']> 50000]
# Out:
#     Order_ID        Date Customer_ID Customer_Name Region Product  \
# 7       1008  2024-01-12        C008         Sneha   West  Laptop
# 15      1016  2024-01-20        C006         Pooja  North  Laptop
# 21      1022  2024-01-26        C002        Anjali  North  Laptop
# 28      1029  2024-02-02        C009         Vikas  South  Laptop
#
#        Category  Quantity  Price  Discount Payment_Method  final_price  \
# 7   Electronics         1  60000      4000           Card        56000
# 15  Electronics         1  58000      3000            UPI        55000
# 21  Electronics         1  62000      5000           Card        57000
# 28  Electronics         1  57000      4000           Card        53000
#
#     Total_sales
# 7         56000
# 15        55000
# 21        57000
# 28        53000

# %% [markdown]
# df = df.rename(columns={'Customer_Name': 'Name'})

# %%
df.sort_values(by='final_price',ascending=False)
# Out:
#     Order_ID        Date Customer_ID Customer_Name Region     Product  \
# 21      1022  2024-01-26        C002        Anjali  North      Laptop
# 7       1008  2024-01-12        C008         Sneha   West      Laptop
# 15      1016  2024-01-20        C006         Pooja  North      Laptop
# 28      1029  2024-02-02        C009         Vikas  South      Laptop
# 0       1001  2024-01-05        C001          Ravi  South      Laptop
# 3       1004  2024-01-08        C004         Meena   West      Tablet
# 23      1024  2024-01-28        C004         Meena   West      Tablet
# 16      1017  2024-01-21        C007         Arjun   East      Tablet
# 9       1010  2024-01-14        C010         Kiran  North      Tablet
# 22      1023  2024-01-27        C003         Rohit   East       Phone
# 14      1015  2024-01-19        C005          Amit  South       Phone
# 1       1002  2024-01-06        C002        Anjali  North       Phone
# ...

# %%
df.sort_values(by=['Price','Discount'],ascending=[False,True])
# Out:
#     Order_ID        Date Customer_ID Customer_Name Region     Product  \
# 21      1022  2024-01-26        C002        Anjali  North      Laptop
# 7       1008  2024-01-12        C008         Sneha   West      Laptop
# 15      1016  2024-01-20        C006         Pooja  North      Laptop
# 28      1029  2024-02-02        C009         Vikas  South      Laptop
# 0       1001  2024-01-05        C001          Ravi  South      Laptop
# 3       1004  2024-01-08        C004         Meena   West      Tablet
# 23      1024  2024-01-28        C004         Meena   West      Tablet
# 16      1017  2024-01-21        C007         Arjun   East      Tablet
# 9       1010  2024-01-14        C010         Kiran  North      Tablet
# 22      1023  2024-01-27        C003         Rohit   East       Phone
# 14      1015  2024-01-19        C005          Amit  South       Phone
# 1       1002  2024-01-06        C002        Anjali  North       Phone
# ...

# %%
df[(df['Payment_Method']=='UPI') & (df['Category']=='Electronics')]
# Out:
#     Order_ID        Date Customer_ID Customer_Name Region  Product  \
# 0       1001  2024-01-05        C001          Ravi  South   Laptop
# 3       1004  2024-01-08        C004         Meena   West   Tablet
# 6       1007  2024-01-11        C007         Arjun   East  Monitor
# 8       1009  2024-01-13        C009         Vikas  South    Phone
# 13      1014  2024-01-18        C004         Meena   West  Monitor
# 15      1016  2024-01-20        C006         Pooja  North   Laptop
# 20      1021  2024-01-25        C001          Ravi  South  Monitor
# 22      1023  2024-01-27        C003         Rohit   East    Phone
# 27      1028  2024-02-01        C008         Sneha   West  Monitor
#
#        Category  Quantity  Price  Discount Payment_Method  final_price  \
# 0   Electronics         1  55000      5000            UPI        50000
# 3   Electronics         1  30000      3000            UPI        27000
# 6   Electronics         1  15000      1500            UPI        13500
# ...

# %%
df.groupby('Region')['final_price'].sum()
# Out:
# Region
# East      61000
# North    175050
# South    156800
# West     137350
# Name: final_price, dtype: int64

# %%
df.groupby('Category')['final_price'].sum()
# Out:
# Category
# Accessories     11700
# Electronics    518500
# Name: final_price, dtype: int64

# %% [markdown]
# Find top 3 customers based on total purchase amount.

# %%
df.groupby('Customer_Name')['Total_sales'].sum().sort_values(ascending = False).head(3)
# Out:
# Customer_Name
# Anjali    94400
# Kiran     85950
# Meena     79500
# Name: Total_sales, dtype: int64

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI     12
# Card     9
# Cash     9
# Name: count, dtype: int64

# %%
df['Revenue'] = df['Total_sales']* df['Quantity']

# %%
df.head(1)
# Out:
#    Order_ID        Date Customer_ID Customer_Name Region Product     Category  \
# 0      1001  2024-01-05        C001          Ravi  South  Laptop  Electronics
#
#    Quantity  Price  Discount Payment_Method  final_price  Total_sales  Revenue
# 0         1  55000      5000            UPI        50000        50000    50000

# %%
df.groupby('Category')['Revenue'].sum().sort_values(ascending=False).head(1)
# Out:
# Category
# Electronics    938000
# Name: Revenue, dtype: int64
